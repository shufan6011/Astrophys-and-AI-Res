# %% [markdown]
# <a href="https://colab.research.google.com/github/shufan6011/Astrophys-and-AI-Res/blob/main/Step_11_GMMs_for_GW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Update:
# Use GPU instead of CPU for faster model training
# GMM is unsupervised, so labels aren't necessary
# This GMM identifies the most deviated outlier as event

# %% [markdown]
# # Data Preprocessing & functions

# %%
import numpy as np
import pandas as pd
import requests, os
import matplotlib.pyplot as plt
from scipy.signal import butter, filtfilt
from sklearn.preprocessing import StandardScaler
from sklearn.mixture import GaussianMixture
import joblib

import warnings
warnings.filterwarnings('ignore')

# %%
# Go to https://gwosc.org
# Find info required below (GPS time & detector)

# %%
# Set GPS time:
t_start = 1126259462.4
t_end = 1126259462.4 # For specific events, make t_end the same as t_start

# Choose detector (H1, L1, or V1)
detector = 'H1'

# %%
# %config InlineBackend.figure_format = 'retina'

try:
    from gwpy.timeseries import TimeSeries
except:
    ! pip install -q "gwpy==3.0.8"
    ! pip install -q "matplotlib==3.9.0"
    ! pip install -q "astropy==6.1.0"
    from gwpy.timeseries import TimeSeries
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 1.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for ligo-segments (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 28.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 19.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 51.6 MB/s eta 0:00:00

# %%
from gwosc.locate import get_urls
url = get_urls(detector, t_start, t_end)[-1]

# If an event is chosen, then its info will be shown in url
print('Downloading: ' , url)
fn = os.path.basename(url)
with open(fn,'wb') as strainfile:
    straindata = requests.get(url)
    strainfile.write(straindata.content)
# Out:
# Downloading:  http://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126257415-4096.hdf5

# %%
# Read strain data
strain = TimeSeries.read(fn,format='hdf5.gwosc')

# Examine an interval closely
# center = int(t_start)
# strain = strain.crop(center-0.2, center+0.1)

# Extract time and strain vals
timestamps = strain.times.value
strain_values = strain.value

# Store data in pd df
data = pd.DataFrame({
    'time': timestamps,
    'strain': strain_values
})

# %% [markdown]
# ## Handling Missing Values

# %%
# Drop rows with missing vals
data = data.dropna()

print("\nMissing vals after cleaning:")
print(data.isnull().sum())
# Out:
# Missing vals after cleaning:
# time      0
# strain    0
# dtype: int64

# %% [markdown]
# ## Data Noise Filtering

# %%
# Band-pass filter function
def butter_bandpass(lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a

def bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = filtfilt(b, a, data)
    return y

# Filter params
lowcut = 20  # Low cutoff frequency (Hz)
highcut = 500  # High cutoff frequency (Hz)

# Band-pass filter strain data
data['strain'] = bandpass_filter(data['strain'], lowcut, highcut, 4096)

# %% [markdown]
# ## Data Normalization

# %%
# Normalize strain data
scaler = StandardScaler()
data['strain'] = scaler.fit_transform(data[['strain']])

# %% [markdown]
# ## Data Inspection

# %%
# Inspect first few rows
print("First few rows of data:")
print(data.head())

# Inspect col headers
print("\nCol headers:")
print(data.columns)

# Summary stats
print("\nSummary stats:")
print(data.describe())

# Check for missing vals
print("\nMissing vals in each col:")
print(data.isnull().sum())

# Check sampling frequency
print(f"\nSampling frequency: {strain.sample_rate} Hz")
fs = 4096 # Change this if sampling frequency is different

# Redef original strain w/ preprocessed data
strain = TimeSeries(data['strain'].values, times=timestamps, sample_rate=fs)
# Out:
# First few rows of data:
#            time    strain
# 0  1.126257e+09 -2.509169
# 1  1.126257e+09  0.070279
# 2  1.126257e+09  2.209692
# 3  1.126257e+09  3.618610
# 4  1.126257e+09  4.256310
#
# Col headers:
# Index(['time', 'strain'], dtype='object')
#
# Summary stats:
#                time        strain
# count  1.677722e+07  1.677722e+07
# mean   1.126259e+09  3.306817e-17
# std    1.182413e+03  1.000000e+00
# min    1.126257e+09 -3.686865e+00
# 25%    1.126258e+09 -7.088866e-01
# 50%    1.126259e+09  1.167620e-03
# 75%    1.126260e+09  7.087774e-01
# max    1.126262e+09  4.284805e+00
#
# Missing vals in each col:
# time      0
# strain    0
# dtype: int64
#
# Sampling frequency: 4096.0 Hz Hz

# %% [markdown]
# ## Data Augmentation

# %%
def augment_data(data, labels):
    augmented_data = []
    augmented_labels = []
    for d, l in zip(data, labels):
        augmented_data.append(d)
        augmented_labels.append(l)
        augmented_data.append(np.flip(d, axis=0))
        augmented_labels.append(l)
        noise = np.random.normal(0, 0.1, d.shape)
        augmented_data.append(d + noise)
        augmented_labels.append(l)
    return np.array(augmented_data), np.array(augmented_labels)

# %% [markdown]
# ## Data Segmenting & Labeling

# %%
def create_segments_and_labels(strain, event_time, window_size, sample_rate):
    # Resample strain to desired sample rate (if necessary)
    strain = strain.resample(sample_rate)

    # Def segments and labels ls
    segments = []
    labels = []

    # Calc # of samples per segment
    segment_length = int(window_size * sample_rate)

    # Create segments and labels
    for i in range(0, len(strain) - segment_length, segment_length):
        segment = strain[i:i + segment_length]
        segments.append(segment.value)

        # Label based on event presence
        if segment.times.value[0] <= event_time <= segment.times.value[-1]:
            labels.append(1)  # Event present
        else:
            labels.append(0)  # No event

    # Convert to np arrays
    segments = np.array(segments)
    labels = np.array(labels)

    print(f"Segments shape: {segments.shape}")
    print(f"Labels shape: {labels.shape}")

    # Verify segments
    print("First few segments:")
    print(segments[:2])

    return segments, labels

# %% [markdown]
# ## Final Product

# %%
def save_model(model_filename):
    # Save model
    joblib.dump(model, model_filename)
    print(f"Model saved as {model_filename}")

# %% [markdown]
# # GMM

# %% [markdown]
# ## Segments Labeling

# %%
segments, labels = create_segments_and_labels(strain, t_start, 2, 1024)
# Out:
# Segments shape: (2047, 2048)
# Labels shape: (2047,)
# First few segments:
# [[-2.50916938  4.33476718  2.86640468 ...  1.21366896
#    0.65737268  0.73727703]
#  [ 0.55530557 -0.71202069 -0.31847015 ... -0.2585079
#   -0.79581982  0.01215234]]

# %% [markdown]
# ## Data Augmentation

# %%
segments_aug, labels_aug = augment_data(segments, labels)

print(f"Original training data shape: {segments.shape}")
print(f"Augmented training data shape: {segments_aug.shape}")
# Out:
# Original training data shape: (2047, 2048)
# Augmented training data shape: (6141, 2048)

# %% [markdown]
# ## Model Training & Evaluation

# %%
# Train gmm
model = GaussianMixture(n_components=1, covariance_type='full', random_state=42)
model.fit(segments_aug)

# Evaluate model
preds = model.predict(segments_aug)
probs = model.predict_proba(segments_aug)
bic = model.bic(segments_aug)
aic = model.aic(segments_aug)

print(f'BIC: {bic}')
print(f'AIC: {aic}')

# Visualize result

log_likelihood = model.score_samples(segments_aug)
threshold = np.percentile(log_likelihood, 0.01)  # Consider the bottom 0.01% as outliers

# data pts w/ log likelihood < threshold are identified as outliers
outliers = log_likelihood < threshold
print(f'Number of outliers detected: {np.sum(outliers)}')

# Visualize results
plt.figure(figsize=(10, 8))
plt.scatter(segments_aug[:, 0], segments_aug[:, 1], c=preds, s=40, cmap='viridis', label='Data Points')
plt.scatter(segments_aug[:, 0][outliers], segments_aug[:, 1][outliers], c='red', s=50, marker='x', label='Outliers (Events)')
plt.title('GMM Clustering of Gravitational Wave Data (Strain vs. Time)')
plt.xlabel('Time')
plt.ylabel('Strain')
plt.colorbar(label='Cluster Label')
plt.legend()
# Out:
# BIC: 3591870.208531903
# AIC: -10527395.721963683
# Number of outliers detected: 1

# %% [markdown]
# ## Final Product

# %%
save_model('gw_gmm.pkl')
# Out:
# Model saved as gw_gmm.pkl
